# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghulRaaj-0812/Data-science-project/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1=pd.read_csv('StudentMarks.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SNO     60 non-null     int64
#  1   REG_NO  60 non-null     int64
#  2   NAME    60 non-null     object
#  3   DM      59 non-null     object
#  4   FLA     59 non-null     object
#  5   CN      58 non-null     object
#  6   BD      59 non-null     object
#  7   COMM    59 non-null     object
#  8   CC      35 non-null     object
#  9   CNS     13 non-null     object
#  10  FS      11 non-null     object
#  11  SRWC    59 non-null     object
# dtypes: int64(2), object(10)
# memory usage: 5.8+ KB

# %%
grade_points={'O':10,'A+':9,'A':8,'B+':7,'B':6,'C':5,'F':0}

# %%
df1['DM_pt']=df1['DM'].map(grade_points)*4

# %%
df1['FLA_pt']=df1['FLA'].map(grade_points)*3
df1['CN_pt']=df1['CC'].map(grade_points)*4
df1['BD_pt']=df1['BD'].map(grade_points)*3

# %%
df1['COMM_pt']=df1['COMM'].map(grade_points)*1

# %%
df1['CC_pt']=df1['CC'].map(grade_points)*3
df1['CNS_pt']=df1['CNS'].map(grade_points)*3
df1['FS_pt']=df1['FS'].map(grade_points)*3
df1['SRWC_pt']=df1['SRWC'].map(grade_points)*3

# %%
columns=['DM_pt','FLA_pt','CN_pt','BD_pt','COMM_pt','CC_pt','CNS_pt','FS_pt','SRWC_pt']

# %%
df1.fillna(0,inplace=True)

# %%
total_credits=21

# %%
df1['SGPA']=df1[columns].sum(axis=1)/total_credits

# %%
df1
# Out:
#     SNO  REG_NO                NAME  DM FLA  CN  BD COMM  CC CNS  ... DM_pt  \
# 0     1   20061           Kiana Lor  A+   A  A+   O    O   0   0  ...  36.0
# 1     2   20062      Joshua Lonaker   A  B+   A   A    o   A   0  ...  32.0
# 2     3   20063       Dakota Blanco  A+   A  A+  A+    O   A   0  ...  36.0
# 3     4   20064     Natasha Yarusso  A+  B+  A+   O    O   0   0  ...  36.0
# 4     5   20065      Brooke Cazares   A   A   A  A+    O   A   0  ...  32.0
# 5     6   20066    Rochelle Johnson   A   A   A   O    O   0   0  ...  32.0
# 6     7   20067          Joey Abreu   O  A+  A+  A+    O   A   0  ...  40.0
# 7     8   20068      Preston Suarez  A+   A   A  A+   A+   A   0  ...  36.0
# 8     9   20069            Lee Dong  B+  B+   A  A+    O  B+   0  ...  28.0
# 9    10   20070       Maa'iz al-Dia  B+   C   A   A    O   0  B+  ...  28.0
# 10   11   20071      Maja Nicholson   A  A+  A+   O    O   0   0  ...  32.0
# 11   12   20072        Sasha Jansen   O   O   O   O    O   A   0  ...  40.0
# 12   13   20073   Alexander Sherman  A+   A   A  A+    O  B+   0  ...  36.0
# 13   14   20074       Edgar Sanchez   A   A   O   O    O  A+   0  ...  32.0
# 14   15   20075        Kolbi Strunk  A+   A   A   O    O   A   0  ...  36.0
# 15   16   20076       Brittany Sath  A+   A  A+   A    O   A   0  ...  36.0
# 16   17   20077        Meggan Smith  A+  A+   O  A+    O   0   0  ...  36.0
# 17   18   20078      Ericka Arreola   A  A+  A+   A    O   0   A  ...  32.0
# 18   19   20079          David Pulc   O  A+  A+   O    O   A   0  ...  40.0
# 19   20   20080         Kyle Luckey  A+  A+  A+  A+    O  A+   0  ...  36.0
# 20   21   20081          Rojesh Her   A   A   A  A+    O  B+   0  ...  32.0
# 21   22   20082         David Weber   O  A+   O   O    O  A+   0  ...  40.0
# 22   23   20083       Rachel Jambor   A   A  A+   A   B+   A   0  ...  32.0
# 23   24   20084  Mus'ab al-Moustafa   O  A+   0   A    O  A+   0  ...  40.0
# 24   25   20085         Sila Nguyen  A+  A+  A+   O    O   0   O  ...  36.0
# 25   26   20086      Samantha Hicks   A  B+  B+   A    O  B+   0  ...  32.0
# 26   27   20087      Angela Harding  A+   A  A+  A+    O   A   0  ...  36.0
# 27   28   20088     Brandon Barbour  A+  A+  A+   O    O   A   0  ...  36.0
# 28   29   20089        Reilly Wagar   A  A+  A+   O    O   0   0  ...  32.0
# 29   30   20090     Victoria Ibarra  A+  A+  A+  A+    O  A+   0  ...  36.0
# 30   31   20091        Dakota Wirth   A  B+   A   A    O   0  A+  ...  32.0
# 31   32   20092      Lauren Klocker  A+  B+  B+   O    O   0   A  ...  36.0
# 32   33   20093      Michael Benson  A+  A+  B+   O   A+   0   A  ...  36.0
# 33   34   20094          Sean Rozga   O   O  A+   O    O  A+   0  ...  40.0
# 34   35   20095      Cody Vermeylen  A+   A   O  A+   A+  A+   0  ...  36.0
# 35   36   20096   Kinaana al-Jamail   O   A  A+   O    O   0  A+  ...  40.0
# 36   37   20097       Daniel Garcia   O   O   O   O    O  A+   0  ...  40.0
# 37   38   20098       Katrina Saito   O   O  A+   O    O   A   0  ...  40.0
# 38   39   20099     Joshua Galloway   A   B   A   A    O   0   A  ...  32.0
# 39   40   20100       Aylin Mendoza   O   O   O  A+    O   A   0  ...  40.0
# 40   41   20101         Sharon Fyfe  A+   A  A+  A+    O   0   0  ...  36.0
# 41   42   20102  Afnaan el-Mohammed  A+   A  A+   O    O   0   0  ...  36.0
# 42   43   20103      Jesse Williams  A+   A  A+  A+    o   A   0  ...  36.0
# 43   44   20104     Kenny Fukushima   O   O   O   O    O   0   0  ...  40.0
# 44   45   20105     Tawnie Glaisher   A  B+   A  A+    O   A   0  ...  32.0
# 45   46   20106     Britany Stevens   0   0   0   0    0   0   0  ...   0.0
# 46   47   20107          Alan Trinh  A+  B+   A   A   B+  B+   0  ...  36.0
# 47   48   20108            Zoe Kern   O  A+   O   O    O  A+   0  ...  40.0
# 48   49   20109      Sidney Beavers  B+   A  A+  A+    O   A   0  ...  28.0
# 49   50   20110      Miriam Aguilar  B+   A  A+   O    O   0  A+  ...  28.0
# 50   51   20111          Issac Mata  A+   O  A+   O    O   0   0  ...  36.0
# 51   52   20112         Hannah Uren   A   A  A+  A+    O  B+   0  ...  32.0
# 52   53   20113     Zachary Bradley  A+  A+   O  A+    O   0   0  ...  36.0
# 53   54   20114      Moira Buttitto  A+  A+   O   A    A   A   0  ...  36.0
# 54   55   20115       Nicole Humpal   O  A+   O   O    O   0  A+  ...  40.0
# 55   56   20116    Georgia Williams   O   O   O   O    O   0   O  ...  40.0
# 56   57   20117        Connor Ferry  A+   O   O  A+    O   0  A+  ...  36.0
# 57   58   20118        Amanda Tatum  B+  B+   A  A+    O  B+   0  ...  28.0
# 58   59   20119   Cameron Steinberg   A  A+  A+  A+    O   0   A  ...  32.0
# 59   60   20120    Shuraih el-Karim  B+   A  A+   O    O   A   0  ...  28.0
#
#    FLA_pt  CN_pt  BD_pt  COMM_pt  CC_pt  CNS_pt  FS_pt  SRWC_pt      SGPA
# 0    24.0    0.0   30.0     10.0    0.0     0.0   27.0     27.0  7.333333
# 1    21.0   32.0   24.0      0.0   24.0     0.0    0.0     24.0  7.476190
# 2    24.0   32.0   27.0     10.0   24.0     0.0    0.0     24.0  8.428571
# 3    21.0    0.0   30.0     10.0    0.0     0.0   27.0     24.0  7.047619
# 4    24.0   32.0   27.0     10.0   24.0     0.0    0.0     24.0  8.238095
# 5    24.0    0.0   30.0     10.0    0.0     0.0   27.0     21.0  6.857143
# 6    27.0   32.0   27.0     10.0   24.0     0.0    0.0     24.0  8.761905
# 7    24.0   32.0   27.0      9.0   24.0     0.0    0.0     21.0  8.238095
# 8    21.0   28.0   27.0     10.0   21.0     0.0    0.0     24.0  7.571429
# 9    15.0    0.0   24.0     10.0    0.0    21.0    0.0     18.0  5.523810
# 10   27.0    0.0   30.0     10.0    0.0     0.0   27.0     27.0  7.285714
# 11   30.0   32.0   30.0     10.0   24.0     0.0    0.0     24.0  9.047619
# 12   24.0   28.0   27.0     10.0   21.0     0.0    0.0     24.0  8.095238
# 13   24.0   36.0   30.0     10.0   27.0     0.0    0.0     24.0  8.714286
# 14   24.0   32.0   30.0     10.0   24.0     0.0    0.0     24.0  8.571429
# 15   24.0   32.0   24.0     10.0   24.0     0.0    0.0     24.0  8.285714
# 16   27.0    0.0   27.0     10.0    0.0     0.0   27.0     27.0  7.333333
# 17   27.0    0.0   24.0     10.0    0.0    24.0    0.0     21.0  6.571429
# 18   27.0   32.0   30.0     10.0   24.0     0.0    0.0     30.0  9.190476
# 19   27.0   36.0   27.0     10.0   27.0     0.0    0.0     27.0  9.047619
# 20   24.0   28.0   27.0     10.0   21.0     0.0    0.0     24.0  7.904762
# 21   27.0   36.0   30.0     10.0   27.0     0.0    0.0     27.0  9.380952
# 22   24.0   32.0   24.0      7.0   24.0     0.0    0.0     24.0  7.952381
# 58   27.0    0.0   27.0     10.0    0.0    24.0    0.0     24.0  6.857143
# 59   24.0   32.0   30.0     10.0   24.0     0.0    0.0     21.0  8.047619
#
# [60 rows x 22 columns]

# %%
df1[['REG_NO','NAME','SGPA']].sort_values('SGPA',ascending=False)
# Out:
#     REG_NO                NAME      SGPA
# 33   20094          Sean Rozga  9.523810
# 47   20108            Zoe Kern  9.523810
# 21   20082         David Weber  9.380952
# 36   20097       Daniel Garcia  9.380952
# 37   20098       Katrina Saito  9.190476
# 18   20079          David Pulc  9.190476
# 23   20084  Mus'ab al-Moustafa  9.095238
# 19   20080         Kyle Luckey  9.047619
# 11   20072        Sasha Jansen  9.047619
# 29   20090     Victoria Ibarra  8.904762
# 39   20100       Aylin Mendoza  8.904762
# 6    20067          Joey Abreu  8.761905
# 34   20095      Cody Vermeylen  8.714286
# 27   20088     Brandon Barbour  8.714286
# 13   20074       Edgar Sanchez  8.714286
# 14   20075        Kolbi Strunk  8.571429
# 26   20087      Angela Harding  8.571429
# 2    20063       Dakota Blanco  8.428571
# 53   20114      Moira Buttitto  8.333333
# 15   20076       Brittany Sath  8.285714
# 7    20068      Preston Suarez  8.238095
# 4    20065      Brooke Cazares  8.238095
# 44   20105     Tawnie Glaisher  8.095238
# 12   20073   Alexander Sherman  8.095238
# 48   20109      Sidney Beavers  8.047619
# 59   20120    Shuraih el-Karim  8.047619
# 42   20103      Jesse Williams  7.952381
# 22   20083       Rachel Jambor  7.952381
# 55   20116    Georgia Williams  7.952381
# 51   20112         Hannah Uren  7.904762
# 20   20081          Rojesh Her  7.904762
# 43   20104     Kenny Fukushima  7.809524
# 24   20085         Sila Nguyen  7.761905
# 54   20115       Nicole Humpal  7.666667
# 25   20086      Samantha Hicks  7.619048
# 50   20111          Issac Mata  7.619048
# 8    20069            Lee Dong  7.571429
# 57   20118        Amanda Tatum  7.571429
# 46   20107          Alan Trinh  7.523810
# 1    20062      Joshua Lonaker  7.476190
# 56   20117        Connor Ferry  7.476190
# 35   20096   Kinaana al-Jamail  7.380952
# 52   20113     Zachary Bradley  7.333333
# 0    20061           Kiana Lor  7.333333
# 41   20102  Afnaan el-Mohammed  7.333333
# 16   20077        Meggan Smith  7.333333
# 32   20093      Michael Benson  7.285714
# 10   20071      Maja Nicholson  7.285714
# 40   20101         Sharon Fyfe  7.047619
# 31   20092      Lauren Klocker  7.047619
# 3    20064     Natasha Yarusso  7.047619
# 28   20089        Reilly Wagar  6.857143
# 5    20066    Rochelle Johnson  6.857143
# 58   20119   Cameron Steinberg  6.857143
# 49   20110      Miriam Aguilar  6.809524
# 17   20078      Ericka Arreola  6.571429
# 30   20091        Dakota Wirth  6.428571
# 38   20099     Joshua Galloway  6.142857
# 9    20070       Maa'iz al-Dia  5.523810
# 45   20106     Britany Stevens  0.000000
